# %%
# !pip install numpy matplotlib scipy -q

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.core.wormhole import WormHole
from src.core.wormhole_with_camera import WormHoleWithCamera

# %%
wormhole = WormHole(r_max=2.5, b=1)

# %%
rt, x1, y1, z1 = wormhole.projection(num_particles=100, flag='regular')
wormhole.visualize(rt, x1, y1, z1)  
wormhole.visualize(rt, x1, y1, z1, static_view=True)
# Out:
# /Users/n.valieva/Desktop/wormhole_visualization/.venv/lib/python3.12/site-packages/matplotlib/animation.py:908: UserWarning: Animation was deleted without rendering anything. This is most likely not intended. To prevent deletion, assign the Animation to a variable, e.g. `anim`, that exists until you output the Animation using `plt.show()` or `anim.save()`.
#   warnings.warn(

# %%
rt, x2, y2, z2 = wormhole.projection(num_particles=100, flag='singular')
wormhole.visualize(rt, x2, y2, z2, alpha=0.1)  
wormhole.visualize(rt, x2, y2, z2, alpha=0.1, static_view=True)

# %%
wormhole_cam = WormHoleWithCamera(r_max=2.5, b=1)

# %%
rt, x1, y1, z1 = wormhole_cam.projection(num_particles=10, flag='regular')
wormhole_cam.visualize_with_camera(x1, y1, z1, alpha=0.5)

# %%
rt, x2, y2, z2 = wormhole_cam.projection(num_particles=10, flag='singular')
wormhole_cam.visualize_with_camera(x2, y2, z2, alpha=0.5)
